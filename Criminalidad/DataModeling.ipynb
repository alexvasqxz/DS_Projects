# %% [markdown]
# # Data Modeling

# %% [markdown]
# ## Overview
# For this part we will:
# 1. Create a classification column to brain storm some ideas we might have when it comes to building our prediction models
# 2. Create numeric target value columns in order to later on implement with prediction models

# %% [markdown]
# ### 1. Adding classification label columns

# %%
import pandas as pd

data = pd.read_csv("data_files/data_preparation.csv")
data.groupby("alcaldia_hechos")["riesgo_delito"].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='alcaldia_hechos'>
